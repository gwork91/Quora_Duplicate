# %%
import re
import string
import pandas as pd
import numpy as np
import itertools
import HTMLParser
html_parser = HTMLParser.HTMLParser()
from scipy.spatial.distance import cosine, cityblock, jaccard, canberra, euclidean, minkowski, braycurtis
from scipy.stats import skew, kurtosis
import json
from joblib import Parallel, delayed
import multiprocessing

from gensim.models import word2vec
from nltk.stem.porter import *
stemmer = PorterStemmer()
main_words = re.compile(r"\w+",re.I)
from nltk.corpus import stopwords
from gensim import corpora
#nltk.data.path
# Out:
# C:\Program Files\Anaconda2\lib\site-packages\gensim-2.0.0-py2.7-win-amd64.egg\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
train_data = pd.read_csv('train.csv',sep=',')
test_data = pd.read_csv('test.csv',sep=',')

# %%
# Row Ids with empty string
# Train : question1 () , question2 (105780,201841 )
# Test : question1 (1046690,1461432 ) , question2 (379205,817520, 943911 , 1270024)

# %%
def apos_fn(row_ini):
    apost_ =  {"do not" : " don’t",  "will not" : " won’t",  "it’s" : " it is",  "can’t" : " can not",  "I’ll" : " I will ",  "I’ve" : " I have",  "you're" : " you are", 
            "didn't" : " did not",  "she's" : " she is",  "they're" : " they are",  "we're" : " we are",  "you've" : " you have",  "aren’t" : " are not",  "she'd" : " she would", 
            "let's" : " let us",  "we’ve" : " we have",  "couldn’t" : " could not",  "who’s" : " who is", "what's":" what is"}
    words = row_ini.split()
    final_row = [apost_[word] if word in apost_ else word for word in words]
    final_row = " ".join(final_row)
    return final_row

# %%
def remove_stop(row_ini, stw):
    words = set(map(lambda word : word.lower().strip(), row_ini.split(" ") ))
#    stop_words = list(["ax","dir","na","i","you","edu","s","t","m","can","lines","re","what","there","all","we","one","the","of","or","in","for","by","on","but","is","in","-","ã","a","not","with","as","was","if","they","are","this","and","it","have","from","at","my","be","by","not","that","to","div","may","please","ok","ltr","n","don","na","\u0081","a","an",",","from","com","org","like","likes","so"])
    words = [word for word in words if word not in stw]
    row_fin = " ".join(words)
    return row_fin

# %%
def row_clean(input_col):
    #removing html characters
    input_col = input_col.apply(lambda row: html_parser.unescape(row))
    # decoding
    input_col = input_col.apply(lambda row: row.decode("utf8").encode('ascii','ignore'))
    #digits
    input_col = input_col.apply(lambda row: re.sub("\d+", " ", row))
    #punctuation
    input_col = input_col.apply(lambda row: row.translate(None, string.punctuation) )
    #links
    input_col = input_col.apply(lambda row: re.sub(r'^https?:\/\/.*[\r\n]*', '', row, flags=re.MULTILINE) )    
    # proper word standards
    input_col = input_col.apply(lambda row: ''.join(''.join(s)[:2] for _, s in itertools.groupby(row)) )
    # to lower and removing stopwords
    stw = stopwords.words('english')
    input_col = input_col.apply(lambda row: remove_stop(row, stw))
    # attached words 
#    input_col = input_col.apply(lambda row: " ".join(re.findall('[A-Z][^A-Z]*', row)) )
    # removing apostrophe to proper words
    input_col = input_col.apply(lambda row: apos_fn(row))
        #mutliple space
    input_col = input_col.apply(lambda row: re.sub('\s+', ' ', row).strip() )
    
    return input_col

# %%
def fill_empty_rows(input_df):
    input_df.question1.fillna('',inplace=True)
    input_df['que1_clean'] = row_clean(input_df.question1)    
    input_df.question2.fillna('',inplace=True)
    input_df['que2_clean'] = row_clean(input_df.question2)
    return input_df

# %%
train_data = fill_empty_rows(train_data)
test_data = fill_empty_rows(test_data)

# %%
print train_data.columns
print " --- "
print test_data.columns
print " --- "
print train_data.shape
print " --- "
print test_data.shape
# Out:
# Index([u'id', u'qid1', u'qid2', u'question1', u'question2', u'is_duplicate',
#        u'que1_clean', u'que2_clean'],
#       dtype='object')
#  ---
# Index([u'test_id', u'question1', u'question2', u'que1_clean', u'que2_clean'], dtype='object')
#  ---
# (404290, 8)
#  ---
# (2345796, 5)

# %%
def que_tokens(input_col):
    que_tokened = []
    input_col.apply(lambda row: que_tokened.append([stemmer.stem(i.lower()) for i in main_words.findall(row) ]) )
    return que_tokened

# Train
train_data['que1_clean_tokens'] = que_tokens(train_data.que1_clean)
train_data['que2_clean_tokens'] = que_tokens(train_data.que2_clean)
# Test
test_data['que1_clean_tokens'] = que_tokens(test_data.que1_clean)
test_data['que2_clean_tokens'] = que_tokens(test_data.que2_clean)

# %%
def question_freq(input_df):
    # Features with frequency of questions in their respective columns
    input_df['q1_freq_in_q1'] = input_df.groupby('question1')['question1'].transform('count')
    input_df['q2_freq_in_q2'] = input_df.groupby('question2')['question2'].transform('count')
    
    # Features with frequency of each of the question1 and question2 in both the columns of the input_df
    qid_1_2 = pd.DataFrame({'qid_count':input_df[['question1','question2']].stack().value_counts()})
    qid_1_2['question']= qid_1_2.index
    qid_1_2.reset_index(drop=True, inplace=True)

    input_df = pd.merge(input_df, qid_1_2, left_on=['question1'],right_on=['question'],how='left', right_index=False)
    input_df.drop('question',inplace=True, axis=1)
    input_df.rename(columns={'qid_count': 'q1_freq_in_q1q2'}, inplace=True)
    input_df = pd.merge(input_df, qid_1_2, left_on=['question2'],right_on=['question'],how='left', right_index=False)
    input_df.drop('question',inplace=True, axis=1)
    input_df.rename(columns={'qid_count': 'q2_freq_in_q1q2'}, inplace=True)
    
    return input_df

# %%
train_data = question_freq(train_data)
test_data = question_freq(test_data)

# %%
sentence_list = []
sentence_list = list(train_data.que1_clean_tokens)+list(train_data.que2_clean_tokens) + list(test_data.que1_clean_tokens)+list(test_data.que2_clean_tokens)

# %%
# word2vec parameters
num_features = 300    # Word-vector dimensionality                      
min_word_count = 1    # Min word count                        
num_workers = 6       # Threads
context = 10          # Context window size                                                                                    
downsampling = 1e-3   # Downsample setting for frequent words

import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
# To get the logs of the word2vec model

# %%
#test_data.to_csv("test_w2v.csv", index=False, sep=',')
#train_data.to_csv("train_w2v.csv", index=False, sep=',')
test_data = pd.read_csv("test_w2v.csv", sep=',')
train_data = pd.read_csv("train_w2v.csv", sep=',')

# %%
train_data.drop(['qid1','qid2','question1','question2','que1_clean','que2_clean'], inplace=True, axis=1)
print train_data.columns
# Out:
# Index([u'id', u'is_duplicate', u'que1_clean_tokens', u'que2_clean_tokens',
#        u'q1_freq_in_q1', u'q2_freq_in_q2', u'q1_freq_in_q1q2',
#        u'q2_freq_in_q1q2'],
#       dtype='object')

# %%
test_data.drop(['question1','question2','que1_clean','que2_clean'], inplace=True, axis=1)
print test_data.columns
# Out:
# Index([u'test_id', u'que1_clean_tokens', u'que2_clean_tokens',
#        u'q1_freq_in_q1', u'q2_freq_in_q2', u'q1_freq_in_q1q2',
#        u'q2_freq_in_q1q2'],
#       dtype='object')

# %%
model_300_train_test = word2vec.Word2Vec(sentence_list, workers=num_workers, size=num_features, min_count = min_word_count, 
                          window = context, sample = downsampling)

model_name = "model_300_1min_10c_train_test"
model_300_train_test.save(model_name)
# Out:
# 2017-05-18 22:23:17,226 : INFO : collecting all words and their counts
# 2017-05-18 22:23:17,226 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-05-18 22:23:17,267 : INFO : PROGRESS: at sentence #10000, processed 52328 words, keeping 8747 word types
# 2017-05-18 22:23:17,316 : INFO : PROGRESS: at sentence #20000, processed 104865 words, keeping 12493 word types
# 2017-05-18 22:23:17,365 : INFO : PROGRESS: at sentence #30000, processed 157308 words, keeping 15363 word types
# 2017-05-18 22:23:17,392 : INFO : PROGRESS: at sentence #40000, processed 209243 words, keeping 17649 word types
# 2017-05-18 22:23:17,418 : INFO : PROGRESS: at sentence #50000, processed 261791 words, keeping 19818 word types
# 2017-05-18 22:23:17,463 : INFO : PROGRESS: at sentence #60000, processed 314077 words, keeping 21770 word types
# 2017-05-18 22:23:17,513 : INFO : PROGRESS: at sentence #70000, processed 366410 words, keeping 23497 word types
# 2017-05-18 22:23:17,565 : INFO : PROGRESS: at sentence #80000, processed 418872 words, keeping 24992 word types
# 2017-05-18 22:23:17,618 : INFO : PROGRESS: at sentence #90000, processed 471169 words, keeping 26478 word types
# 2017-05-18 22:23:17,684 : INFO : PROGRESS: at sentence #100000, processed 523539 words, keeping 27956 word types
# 2017-05-18 22:23:17,733 : INFO : PROGRESS: at sentence #110000, processed 575279 words, keeping 29293 word types
# 2017-05-18 22:23:17,786 : INFO : PROGRESS: at sentence #120000, processed 627509 words, keeping 30559 word types
# 2017-05-18 22:23:17,844 : INFO : PROGRESS: at sentence #130000, processed 679918 words, keeping 31856 word types
# 2017-05-18 22:23:17,898 : INFO : PROGRESS: at sentence #140000, processed 732266 words, keeping 33009 word types
# 2017-05-18 22:23:17,954 : INFO : PROGRESS: at sentence #150000, processed 784960 words, keeping 34249 word types
# 2017-05-18 22:23:18,007 : INFO : PROGRESS: at sentence #160000, processed 837580 words, keeping 35451 word types
# 2017-05-18 22:23:18,068 : INFO : PROGRESS: at sentence #170000, processed 890138 words, keeping 36520 word types
# 2017-05-18 22:23:18,121 : INFO : PROGRESS: at sentence #180000, processed 942817 words, keeping 37612 word types
# 2017-05-18 22:23:18,174 : INFO : PROGRESS: at sentence #190000, processed 995153 words, keeping 38631 word types
# 2017-05-18 22:23:18,227 : INFO : PROGRESS: at sentence #200000, processed 1047199 words, keeping 39658 word types
# 2017-05-18 22:23:18,279 : INFO : PROGRESS: at sentence #210000, processed 1099134 words, keeping 40596 word types
# 2017-05-18 22:23:18,331 : INFO : PROGRESS: at sentence #220000, processed 1151385 words, keeping 41504 word types
# 2017-05-18 22:23:19,838 : INFO : PROGRESS: at sentence #500000, processed 2627564 words, keeping 61142 word types
# 2017-05-18 22:23:19,894 : INFO : PROGRESS: at sentence #510000, processed 2679620 words, keeping 61625 word types
# 2017-05-18 22:23:19,948 : INFO : PROGRESS: at sentence #520000, processed 2732282 words, keeping 62092 word types
# 2017-05-18 22:23:20,019 : INFO : PROGRESS: at sentence #530000, processed 2785457 words, keeping 62556 word types
# 2017-05-18 22:23:20,052 : INFO : PROGRESS: at sentence #540000, processed 2838533 words, keeping 63079 word types
# 2017-05-18 22:23:20,101 : INFO : PROGRESS: at sentence #550000, processed 2891989 words, keeping 63596 word types
# 2017-05-18 22:23:20,157 : INFO : PROGRESS: at sentence #560000, processed 2945052 words, keeping 64086 word types
# 2017-05-18 22:23:20,213 : INFO : PROGRESS: at sentence #570000, processed 2998402 words, keeping 64555 word types
# 2017-05-18 22:23:20,276 : INFO : PROGRESS: at sentence #580000, processed 3051729 words, keeping 65000 word types
# 2017-05-18 22:23:20,335 : INFO : PROGRESS: at sentence #590000, processed 3105211 words, keeping 65457 word types
# 2017-05-18 22:23:20,391 : INFO : PROGRESS: at sentence #600000, processed 3157531 words, keeping 65861 word types
# 2017-05-18 22:23:20,459 : INFO : PROGRESS: at sentence #610000, processed 3210539 words, keeping 66330 word types
# 2017-05-18 22:23:20,515 : INFO : PROGRESS: at sentence #620000, processed 3263452 words, keeping 66778 word types
# 2017-05-18 22:23:20,585 : INFO : PROGRESS: at sentence #630000, processed 3316259 words, keeping 67258 word types
# 2017-05-18 22:23:20,644 : INFO : PROGRESS: at sentence #640000, processed 3368498 words, keeping 67689 word types
# 2017-05-18 22:23:20,707 : INFO : PROGRESS: at sentence #650000, processed 3421574 words, keeping 68136 word types
# 2017-05-18 22:23:20,760 : INFO : PROGRESS: at sentence #660000, processed 3474484 words, keeping 68608 word types
# 2017-05-18 22:23:20,816 : INFO : PROGRESS: at sentence #670000, processed 3527795 words, keeping 69075 word types
# 2017-05-18 22:23:20,874 : INFO : PROGRESS: at sentence #680000, processed 3581155 words, keeping 69539 word types
# 2017-05-18 22:23:20,938 : INFO : PROGRESS: at sentence #690000, processed 3634066 words, keeping 69982 word types
# 2017-05-18 22:23:20,996 : INFO : PROGRESS: at sentence #700000, processed 3686931 words, keeping 70430 word types
# 2017-05-18 22:23:21,048 : INFO : PROGRESS: at sentence #710000, processed 3739472 words, keeping 70855 word types
# 2017-05-18 22:23:21,098 : INFO : PROGRESS: at sentence #720000, processed 3792630 words, keeping 71272 word types
# 2017-05-18 22:23:21,154 : INFO : PROGRESS: at sentence #730000, processed 3845169 words, keeping 71675 word types
# 2017-05-18 22:23:21,204 : INFO : PROGRESS: at sentence #740000, processed 3898069 words, keeping 72090 word types
# 2017-05-18 22:23:21,256 : INFO : PROGRESS: at sentence #750000, processed 3950712 words, keeping 72508 word types
# 2017-05-18 22:23:21,305 : INFO : PROGRESS: at sentence #760000, processed 4003810 words, keeping 72927 word types
# 2017-05-18 22:23:21,355 : INFO : PROGRESS: at sentence #770000, processed 4056910 words, keeping 73343 word types
# 2017-05-18 22:23:21,387 : INFO : PROGRESS: at sentence #780000, processed 4109954 words, keeping 73777 word types
# 2017-05-18 22:23:21,437 : INFO : PROGRESS: at sentence #790000, processed 4163042 words, keeping 74216 word types
# 2017-05-18 22:23:21,486 : INFO : PROGRESS: at sentence #800000, processed 4216765 words, keeping 74641 word types
# 2017-05-18 22:23:21,539 : INFO : PROGRESS: at sentence #810000, processed 4270257 words, keeping 75090 word types
# 2017-05-18 22:23:21,592 : INFO : PROGRESS: at sentence #820000, processed 4323859 words, keeping 75772 word types
# 2017-05-18 22:23:21,651 : INFO : PROGRESS: at sentence #830000, processed 4377862 words, keeping 76398 word types
# 2017-05-18 22:23:21,710 : INFO : PROGRESS: at sentence #840000, processed 4432088 words, keeping 77005 word types
# 2017-05-18 22:23:21,770 : INFO : PROGRESS: at sentence #850000, processed 4486209 words, keeping 77573 word types
# 2017-05-18 22:23:21,832 : INFO : PROGRESS: at sentence #860000, processed 4540103 words, keeping 78185 word types
# 2017-05-18 22:23:21,888 : INFO : PROGRESS: at sentence #870000, processed 4594335 words, keeping 78786 word types
# 2017-05-18 22:23:21,943 : INFO : PROGRESS: at sentence #880000, processed 4648463 words, keeping 79409 word types
# 2017-05-18 22:23:22,002 : INFO : PROGRESS: at sentence #890000, processed 4702612 words, keeping 80001 word types
# 2017-05-18 22:23:22,059 : INFO : PROGRESS: at sentence #900000, processed 4756996 words, keeping 80547 word types
# 2017-05-18 22:23:22,112 : INFO : PROGRESS: at sentence #910000, processed 4811373 words, keeping 81092 word types
# 2017-05-18 22:23:22,167 : INFO : PROGRESS: at sentence #920000, processed 4865274 words, keeping 81642 word types
# 2017-05-18 22:23:22,220 : INFO : PROGRESS: at sentence #930000, processed 4919425 words, keeping 82144 word types
# 2017-05-18 22:23:22,283 : INFO : PROGRESS: at sentence #940000, processed 4973999 words, keeping 82619 word types
# 2017-05-18 22:23:22,351 : INFO : PROGRESS: at sentence #950000, processed 5027962 words, keeping 83112 word types
# 2017-05-18 22:23:22,413 : INFO : PROGRESS: at sentence #960000, processed 5082309 words, keeping 83614 word types
# 2017-05-18 22:23:22,470 : INFO : PROGRESS: at sentence #970000, processed 5136524 words, keeping 84052 word types
# 2017-05-18 22:23:22,526 : INFO : PROGRESS: at sentence #980000, processed 5191272 words, keeping 84483 word types
# 2017-05-18 22:23:22,586 : INFO : PROGRESS: at sentence #990000, processed 5245924 words, keeping 84986 word types
# 2017-05-18 22:23:22,657 : INFO : PROGRESS: at sentence #1000000, processed 5300397 words, keeping 85442 word types
# 2017-05-18 22:23:22,720 : INFO : PROGRESS: at sentence #1010000, processed 5354500 words, keeping 85876 word types
# 2017-05-18 22:23:22,778 : INFO : PROGRESS: at sentence #1020000, processed 5408504 words, keeping 86256 word types
# 2017-05-18 22:23:22,838 : INFO : PROGRESS: at sentence #1030000, processed 5462759 words, keeping 86692 word types
# 2017-05-18 22:23:22,892 : INFO : PROGRESS: at sentence #1040000, processed 5516553 words, keeping 87109 word types
# 2017-05-18 22:23:22,964 : INFO : PROGRESS: at sentence #1050000, processed 5570550 words, keeping 87508 word types
# 2017-05-18 22:23:23,045 : INFO : PROGRESS: at sentence #1060000, processed 5623985 words, keeping 87911 word types
# 2017-05-18 22:23:23,108 : INFO : PROGRESS: at sentence #1070000, processed 5678044 words, keeping 88298 word types
# 2017-05-18 22:23:23,178 : INFO : PROGRESS: at sentence #1080000, processed 5731291 words, keeping 88667 word types
# 2017-05-18 22:23:23,242 : INFO : PROGRESS: at sentence #1090000, processed 5785525 words, keeping 89074 word types
# 2017-05-18 22:23:23,305 : INFO : PROGRESS: at sentence #1100000, processed 5840218 words, keeping 89443 word types
# 2017-05-18 22:23:23,372 : INFO : PROGRESS: at sentence #1110000, processed 5894590 words, keeping 89773 word types
# 2017-05-18 22:23:23,438 : INFO : PROGRESS: at sentence #1120000, processed 5948858 words, keeping 90106 word types
# 2017-05-18 22:23:23,503 : INFO : PROGRESS: at sentence #1130000, processed 6003291 words, keeping 90469 word types
# 2017-05-18 22:23:23,561 : INFO : PROGRESS: at sentence #1140000, processed 6057157 words, keeping 90846 word types
# 2017-05-18 22:23:23,624 : INFO : PROGRESS: at sentence #1150000, processed 6111423 words, keeping 91182 word types
# 2017-05-18 22:23:23,681 : INFO : PROGRESS: at sentence #1160000, processed 6166001 words, keeping 91534 word types
# 2017-05-18 22:23:23,743 : INFO : PROGRESS: at sentence #1170000, processed 6220072 words, keeping 91833 word types
# 2017-05-18 22:23:23,819 : INFO : PROGRESS: at sentence #1180000, processed 6274386 words, keeping 92159 word types
# 2017-05-18 22:23:23,878 : INFO : PROGRESS: at sentence #1190000, processed 6328486 words, keeping 92461 word types
# 2017-05-18 22:23:23,940 : INFO : PROGRESS: at sentence #1200000, processed 6382313 words, keeping 92785 word types
# 2017-05-18 22:23:24,007 : INFO : PROGRESS: at sentence #1210000, processed 6436665 words, keeping 93087 word types
# 2017-05-18 22:23:24,068 : INFO : PROGRESS: at sentence #1220000, processed 6490196 words, keeping 93393 word types
# 2017-05-18 22:23:24,128 : INFO : PROGRESS: at sentence #1230000, processed 6543500 words, keeping 93686 word types
# 2017-05-18 22:23:24,187 : INFO : PROGRESS: at sentence #1240000, processed 6597034 words, keeping 93961 word types
# 2017-05-18 22:23:24,250 : INFO : PROGRESS: at sentence #1250000, processed 6651166 words, keeping 94237 word types
# 2017-05-18 22:23:24,312 : INFO : PROGRESS: at sentence #1260000, processed 6705387 words, keeping 94531 word types
# 2017-05-18 22:23:24,384 : INFO : PROGRESS: at sentence #1270000, processed 6759108 words, keeping 94867 word types
# 2017-05-18 22:23:24,444 : INFO : PROGRESS: at sentence #1280000, processed 6813566 words, keeping 95140 word types
# 2017-05-18 22:23:24,502 : INFO : PROGRESS: at sentence #1290000, processed 6867886 words, keeping 95402 word types
# 2017-05-18 22:23:24,565 : INFO : PROGRESS: at sentence #1300000, processed 6922322 words, keeping 95656 word types
# 2017-05-18 22:23:24,621 : INFO : PROGRESS: at sentence #1310000, processed 6976522 words, keeping 95942 word types
# 2017-05-18 22:23:24,676 : INFO : PROGRESS: at sentence #1320000, processed 7030516 words, keeping 96206 word types
# 2017-05-18 22:23:24,730 : INFO : PROGRESS: at sentence #1330000, processed 7084414 words, keeping 96451 word types
# 2017-05-18 22:23:24,786 : INFO : PROGRESS: at sentence #1340000, processed 7138340 words, keeping 96684 word types
# 2017-05-18 22:23:24,844 : INFO : PROGRESS: at sentence #1350000, processed 7192301 words, keeping 96900 word types
# 2017-05-18 22:23:24,898 : INFO : PROGRESS: at sentence #1360000, processed 7246873 words, keeping 97145 word types
# 2017-05-18 22:23:24,960 : INFO : PROGRESS: at sentence #1370000, processed 7301043 words, keeping 97390 word types
# 2017-05-18 22:23:25,052 : INFO : PROGRESS: at sentence #1380000, processed 7355127 words, keeping 97635 word types
# 2017-05-18 22:23:25,078 : INFO : PROGRESS: at sentence #1390000, processed 7409117 words, keeping 97887 word types
# 2017-05-18 22:23:25,134 : INFO : PROGRESS: at sentence #1400000, processed 7463326 words, keeping 98102 word types
# 2017-05-18 22:23:25,188 : INFO : PROGRESS: at sentence #1410000, processed 7517243 words, keeping 98353 word types
# 2017-05-18 22:23:25,247 : INFO : PROGRESS: at sentence #1420000, processed 7571635 words, keeping 98567 word types
# 2017-05-18 22:23:25,306 : INFO : PROGRESS: at sentence #1430000, processed 7625587 words, keeping 98803 word types
# 2017-05-18 22:23:25,364 : INFO : PROGRESS: at sentence #1440000, processed 7679491 words, keeping 98997 word types
# 2017-05-18 22:23:25,421 : INFO : PROGRESS: at sentence #1450000, processed 7733747 words, keeping 99223 word types
# 2017-05-18 22:23:25,477 : INFO : PROGRESS: at sentence #1460000, processed 7788347 words, keeping 99427 word types
# 2017-05-18 22:23:25,533 : INFO : PROGRESS: at sentence #1470000, processed 7842370 words, keeping 99650 word types
# 2017-05-18 22:23:25,592 : INFO : PROGRESS: at sentence #1480000, processed 7896482 words, keeping 99864 word types
# 2017-05-18 22:23:25,663 : INFO : PROGRESS: at sentence #1490000, processed 7950612 words, keeping 100053 word types
# 2017-05-18 22:23:25,746 : INFO : PROGRESS: at sentence #1500000, processed 8005101 words, keeping 100256 word types
# 2017-05-18 22:23:25,809 : INFO : PROGRESS: at sentence #1510000, processed 8059467 words, keeping 100432 word types
# 2017-05-18 22:23:25,874 : INFO : PROGRESS: at sentence #1520000, processed 8113162 words, keeping 100615 word types
# 2017-05-18 22:23:25,931 : INFO : PROGRESS: at sentence #1530000, processed 8167811 words, keeping 100827 word types
# 2017-05-18 22:23:25,997 : INFO : PROGRESS: at sentence #1540000, processed 8221172 words, keeping 101023 word types
# 2017-05-18 22:23:26,056 : INFO : PROGRESS: at sentence #1550000, processed 8275871 words, keeping 101227 word types
# 2017-05-18 22:23:26,117 : INFO : PROGRESS: at sentence #1560000, processed 8330247 words, keeping 101410 word types
# 2017-05-18 22:23:26,174 : INFO : PROGRESS: at sentence #1570000, processed 8384315 words, keeping 101581 word types
# 2017-05-18 22:23:26,246 : INFO : PROGRESS: at sentence #1580000, processed 8438697 words, keeping 101742 word types
# 2017-05-18 22:23:26,302 : INFO : PROGRESS: at sentence #1590000, processed 8492638 words, keeping 101945 word types
# 2017-05-18 22:23:26,365 : INFO : PROGRESS: at sentence #1600000, processed 8546801 words, keeping 102114 word types
# 2017-05-18 22:23:26,431 : INFO : PROGRESS: at sentence #1610000, processed 8600373 words, keeping 102289 word types
# 2017-05-18 22:23:26,493 : INFO : PROGRESS: at sentence #1620000, processed 8654769 words, keeping 102468 word types
# 2017-05-18 22:23:26,553 : INFO : PROGRESS: at sentence #1630000, processed 8709173 words, keeping 102619 word types
# 2017-05-18 22:23:26,608 : INFO : PROGRESS: at sentence #1640000, processed 8763079 words, keeping 102788 word types
# 2017-05-18 22:23:26,667 : INFO : PROGRESS: at sentence #1650000, processed 8817491 words, keeping 102946 word types
# 2017-05-18 22:23:26,737 : INFO : PROGRESS: at sentence #1660000, processed 8871578 words, keeping 103106 word types
# 2017-05-18 22:23:26,798 : INFO : PROGRESS: at sentence #1670000, processed 8925393 words, keeping 103257 word types
# 2017-05-18 22:23:26,861 : INFO : PROGRESS: at sentence #1680000, processed 8979166 words, keeping 103414 word types
# 2017-05-18 22:23:26,920 : INFO : PROGRESS: at sentence #1690000, processed 9033068 words, keeping 103557 word types
# 2017-05-18 22:23:26,974 : INFO : PROGRESS: at sentence #1700000, processed 9086724 words, keeping 103729 word types
# 2017-05-18 22:23:27,033 : INFO : PROGRESS: at sentence #1710000, processed 9140592 words, keeping 103863 word types
# 2017-05-18 22:23:27,108 : INFO : PROGRESS: at sentence #1720000, processed 9195445 words, keeping 103985 word types
# 2017-05-18 22:23:27,174 : INFO : PROGRESS: at sentence #1730000, processed 9249484 words, keeping 104133 word types
# 2017-05-18 22:23:27,237 : INFO : PROGRESS: at sentence #1740000, processed 9303301 words, keeping 104263 word types
# 2017-05-18 22:23:27,306 : INFO : PROGRESS: at sentence #1750000, processed 9357517 words, keeping 104417 word types
# 2017-05-18 22:23:27,381 : INFO : PROGRESS: at sentence #1760000, processed 9411467 words, keeping 104534 word types
# 2017-05-18 22:23:27,440 : INFO : PROGRESS: at sentence #1770000, processed 9465759 words, keeping 104661 word types
# 2017-05-18 22:23:27,506 : INFO : PROGRESS: at sentence #1780000, processed 9519574 words, keeping 104782 word types
# 2017-05-18 22:23:27,563 : INFO : PROGRESS: at sentence #1790000, processed 9573557 words, keeping 104909 word types
# 2017-05-18 22:23:27,624 : INFO : PROGRESS: at sentence #1800000, processed 9627516 words, keeping 105037 word types
# 2017-05-18 22:23:27,681 : INFO : PROGRESS: at sentence #1810000, processed 9681673 words, keeping 105161 word types
# 2017-05-18 22:23:27,743 : INFO : PROGRESS: at sentence #1820000, processed 9735771 words, keeping 105265 word types
# 2017-05-18 22:23:27,799 : INFO : PROGRESS: at sentence #1830000, processed 9790259 words, keeping 105366 word types
# 2017-05-18 22:23:27,859 : INFO : PROGRESS: at sentence #1840000, processed 9844654 words, keeping 105476 word types
words/s, in_qsize 0, out_qsize 0
# 2017-05-18 22:30:59,466 : INFO : PROGRESS: at 94.71% examples, 315100 words/s, in_qsize 0, out_qsize 0
# 2017-05-18 22:31:00,463 : INFO : PROGRESS: at 94.93% examples, 315093 words/s, in_qsize 0, out_qsize 0
# 2017-05-18 22:31:01,506 : INFO : PROGRESS: at 95.16% examples, 315100 words/s, in_qsize 0, out_qsize 0
# 2017-05-18 22:31:02,506 : INFO : PROGRESS: at 95.38% examples, 315099 words/s, in_qsize 0, out_qsize 0
# 2017-05-18 22:31:03,522 : INFO : PROGRESS: at 95.62% examples, 315144 words/s, in_qsize 0, out_qsize 0
# 2017-05-18 22:31:04,543 : INFO : PROGRESS: at 95.84% examples, 315132 words/s, in_qsize 0, out_qsize 0
# 2017-05-18 22:31:05,546 : INFO : PROGRESS: at 96.07% examples, 315147 words/s, in_qsize 0, out_qsize 0
# 2017-05-18 22:31:06,565 : INFO : PROGRESS: at 96.29% examples, 315117 words/s, in_qsize 0, out_qsize 0
# 2017-05-18 22:31:07,555 : INFO : PROGRESS: at 96.52% examples, 315131 words/s, in_qsize 0, out_qsize 0
# 2017-05-18 22:31:08,602 : INFO : PROGRESS: at 96.74% examples, 315130 words/s, in_qsize 0, out_qsize 0
# 2017-05-18 22:31:09,619 : INFO : PROGRESS: at 96.97% examples, 315138 words/s, in_qsize 0, out_qsize 0
# 2017-05-18 22:31:10,644 : INFO : PROGRESS: at 97.21% examples, 315163 words/s, in_qsize 0, out_qsize 0
# 2017-05-18 22:31:11,650 : INFO : PROGRESS: at 97.44% examples, 315163 words/s, in_qsize 0, out_qsize 0
# 2017-05-18 22:31:12,688 : INFO : PROGRESS: at 97.67% examples, 315173 words/s, in_qsize 0, out_qsize 0
# 2017-05-18 22:31:13,681 : INFO : PROGRESS: at 97.91% examples, 315236 words/s, in_qsize 0, out_qsize 0
# 2017-05-18 22:31:14,684 : INFO : PROGRESS: at 98.13% examples, 315227 words/s, in_qsize 0, out_qsize 0
# 2017-05-18 22:31:15,719 : INFO : PROGRESS: at 98.36% examples, 315253 words/s, in_qsize 0, out_qsize 0
# 2017-05-18 22:31:16,769 : INFO : PROGRESS: at 98.59% examples, 315237 words/s, in_qsize 0, out_qsize 0
# 2017-05-18 22:31:17,789 : INFO : PROGRESS: at 98.81% examples, 315202 words/s, in_qsize 0, out_qsize 0
# 2017-05-18 22:31:18,808 : INFO : PROGRESS: at 99.04% examples, 315232 words/s, in_qsize 0, out_qsize 0
# 2017-05-18 22:31:19,842 : INFO : PROGRESS: at 99.26% examples, 315211 words/s, in_qsize 0, out_qsize 0
# 2017-05-18 22:31:20,839 : INFO : PROGRESS: at 99.50% examples, 315234 words/s, in_qsize 0, out_qsize 0
# 2017-05-18 22:31:21,865 : INFO : PROGRESS: at 99.72% examples, 315228 words/s, in_qsize 0, out_qsize 0
# 2017-05-18 22:31:22,907 : INFO : PROGRESS: at 99.97% examples, 315280 words/s, in_qsize 0, out_qsize 0
# 2017-05-18 22:31:22,936 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2017-05-18 22:31:22,940 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2017-05-18 22:31:22,946 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-05-18 22:31:22,954 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-05-18 22:31:22,966 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-05-18 22:31:22,993 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-05-18 22:31:22,996 : INFO : training on 148229780 raw words (141428577 effective words) took 448.6s, 315300 effective words/s
# 2017-05-18 22:31:23,000 : INFO : saving Word2Vec object under model_300_1min_10c_train_test, separately None
# 2017-05-18 22:31:23,005 : INFO : not storing attribute syn0norm
# 2017-05-18 22:31:23,006 : INFO : storing np array 'syn0' to model_300_1min_10c_train_test.wv.syn0.npy
# 2017-05-18 22:31:23,786 : INFO : storing np array 'syn1neg' to model_300_1min_10c_train_test.syn1neg.npy
# 2017-05-18 22:31:24,536 : INFO : not storing attribute cum_table
# 2017-05-18 22:31:26,851 : INFO : saved model_300_1min_10c_train_test

# %%
#model_300_train_test = word2vec.Word2Vec.load('model_300_1min_10c_train_test')

# %%
def sen2Vec(words, model, set_index2word ):
    featureVec = np.zeros((300,), dtype="float32")  # Number of features is 300
    nwords = 0
    for word in words:
        if word in set_index2word :
            nwords = nwords+1
            featureVec = np.add(featureVec, model[word])
    if(nwords>0):
        featureVec = np.divide(featureVec, nwords)
    return featureVec

# %%
def create_similarity(model, input_df):
# Vector for sentence 1 : apply this or json.dumps
#    senvec_1 = sen2Vec(str(" ".join(row[colNames[8]])).split(), model=model)
    # Vector for sentence 2
#    senvec_2 = sen2Vec(str(" ".join(row[colNames[9]])).split(), model=model)
    set_index2word= set(model.wv.index2word)
    
    # Cosine similarity
    input_df['cosine_val']= input_df.apply(
        lambda row: float("{0:.2f}".format(1- cosine( sen2Vec(  json.dumps(row['que1_clean_tokens']) , model, set_index2word),
                               sen2Vec( json.dumps(row['que2_clean_tokens']), model, set_index2word) ) )), axis=1 )
    input_df['cosine_val'].fillna(0, inplace=True)
    
    # Cityblock similarity
    input_df['cityblock_val']= input_df.apply(
        lambda row: float("{0:.2f}".format( cityblock(sen2Vec( json.dumps(row['que1_clean_tokens']) , model, set_index2word),
                               sen2Vec( json.dumps(row['que2_clean_tokens']), model, set_index2word) ) )), axis=1 )
    input_df['cityblock_val'].fillna(0, inplace=True)
    
    # Jaccard similarity
    input_df['jaccard_val']= input_df.apply(
        lambda row: float("{0:.2f}".format( jaccard(sen2Vec( json.dumps(row['que1_clean_tokens']) , model, set_index2word),
                               sen2Vec( json.dumps(row['que2_clean_tokens']), model, set_index2word) ) )), axis=1 )
    input_df['jaccard_val'].fillna(0, inplace=True)
    
    # Canberra similarity
    input_df['canberra_val']= input_df.apply(
        lambda row: float("{0:.2f}".format( canberra(sen2Vec( json.dumps(row['que1_clean_tokens']) , model, set_index2word),
                               sen2Vec( json.dumps(row['que2_clean_tokens']), model, set_index2word) ) )), axis=1 )
    input_df['canberra_val'].fillna(0, inplace=True)
    
    # Euclidean similarity
    input_df['euclidean_val']= input_df.apply(
        lambda row: float("{0:.2f}".format( euclidean(sen2Vec( json.dumps(row['que1_clean_tokens']) , model, set_index2word),
                               sen2Vec( json.dumps(row['que2_clean_tokens']), model, set_index2word) ) )), axis=1 )
    input_df['euclidean_val'].fillna(0, inplace=True)
    
    # Minkowski similarity
    input_df['minkowski_val']= input_df.apply(
        lambda row: float("{0:.2f}".format( minkowski(sen2Vec( json.dumps(row['que1_clean_tokens']) , model, set_index2word),
                               sen2Vec( json.dumps(row['que2_clean_tokens']), model, set_index2word), 3) )), axis=1 )
    input_df['minkowski_val'].fillna(0, inplace=True)
    
    # Braycurtis similarity
    input_df['braycurtis_val']= input_df.apply(
        lambda row: float("{0:.2f}".format( braycurtis(sen2Vec( json.dumps(row['que1_clean_tokens']) , model, set_index2word),
                               sen2Vec( json.dumps(row['que2_clean_tokens']), model, set_index2word) ),2 )), axis=1 )
    input_df['braycurtis_val'].fillna(0, inplace=True)
    
    # Skewness
    input_df['skew_que1']= input_df.apply(
        lambda row: float("{0:.2f}".format( skew(sen2Vec( json.dumps(row['que1_clean_tokens']) , model, set_index2word) ) )), 
                            axis=1 )
    input_df['skew_que1'].fillna(0, inplace=True)
        
    input_df['skew_que2']= input_df.apply(
        lambda row: float("{0:.2f}".format( skew(sen2Vec( json.dumps(row['que2_clean_tokens']) , model, set_index2word) ) )),
                            axis=1 )
    input_df['skew_que2'].fillna(0, inplace=True)
    
    # Kurtosis
    input_df['kurt_que1']= input_df.apply(
        lambda row: float("{0:.2f}".format( kurtosis(sen2Vec( json.dumps(row['que1_clean_tokens']) , model, set_index2word) ))),
                            axis=1 )
    input_df['kurt_que1'].fillna(0, inplace=True)
        
    input_df['kurt_que2']= input_df.apply(
        lambda row: float("{0:.2f}".format( kurtosis(sen2Vec( json.dumps(row['que2_clean_tokens']) , model, set_index2word) ))),
                            axis=1 )
    input_df['kurt_que2'].fillna(0, inplace=True)
    
    return input_df

# %%
# Not used
def applyParallel(dfGrouped, func):
    retLst = Parallel(n_jobs=multiprocessing.cpu_count())(delayed(func)(group) for name, group in dfGrouped)
    return pd.concat(retLst)

# %%
#train_data = applyParallel(train_data.groupby(train_data.index), create_que_vec)
#test_data = applyParallel(test_data.groupby(train_data.index), create_que_vec)

#aa = train_data.iloc[1:10000]
#aa = applyParallel(aa.groupby(aa.index), create_similarity)
#aa = create_similarity( aa)

# %%
train_data = create_similarity(model_300_train_test, train_data)
train_data.drop(['que1_clean_tokens', 'que2_clean_tokens'], inplace=True, axis=1)
train_data.to_csv("train_w2v_feats.csv", index=False, sep=',')
del train_data

# %%
test_data = create_similarity(model_300_train_test, test_data)
test_data.drop(['que1_clean_tokens', 'que2_clean_tokens'], inplace=True, axis=1)
test_data.to_csv("test_w2v_feats.csv", index=False, sep=',')
del test_data

# %%
# Breaking into multiple chunks as size big to upload
test_data = pd.read_csv("test_w2v_feats.csv", sep=',')

# %%
for i in [1,2,3]:
    vars()['test_w2v_feats'+str(i)] = test_data.iloc[((test_data.shape[0]/3)*(i-1)):((test_data.shape[0]/3)*i)]
    vars()['test_w2v_feats'+str(i)].to_csv('test_w2v_feats'+str(i)+'.csv', sep=',', index=False)
    del vars()['test_w2v_feats'+str(i)]

# %%
# Add TF-IDF Features

# %%
# +++++++++++++++++++++++++++++++++++++++
# CODE BELOW THIS CELL HAS NOT BEEN USED!
# PLEASE DO NOT TRY THE CODE BELOW!!!!!
# +++++++++++++++++++++++++++++++++++++++

# %%
# For word similarity
#word1 = 'sun'
#word2 = 'moon'
#cosine_similarity = numpy.dot(model[word1], model[word2])/(numpy.linalg.norm(model[word2])* numpy.linalg.norm(model[word1]))

# %%
"""def quora_dict_creation(input_df):    
    all_tokens = input_df.que1_clean_tokens.tolist()+input_df.que2_clean_tokens.tolist()
    final_dict = corpora.Dictionary(all_tokens)
    final_dict.filter_extremes(no_below=1, no_above=0.9)
    final_dict.compactify()
    return final_dict
quora_dict_ini = quora_dict_creation(aa)

def sent2vec(input_col, quora_dict):
    input_col_vector = [quora_dict.doc2bow(text) for text in input_col.tolist()]
    input_col_matrix = gensim.matutils.corpus2csc(input_col_vector, num_terms=len(quora_dict.token2id))    
    return input_col_matrix.transpose()

que1_clean_matrix = sent2vec(aa.que1_clean_tokens, quora_dict_ini)
que2_clean_matrix = sent2vec(aa.que2_clean_tokens, quora_dict_ini)"""

# %%
"""from sklearn.feature_extraction.text import TfidfVectorizer
aa = train_data.head(10)
corpus= aa.que1_clean
vectorizer = TfidfVectorizer(min_df=1)
X = vectorizer.fit_transform(corpus)
idf = vectorizer.idf_
print dict(zip(vectorizer.get_feature_names(), idf))"""
